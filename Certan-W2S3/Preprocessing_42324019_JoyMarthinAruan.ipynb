# %% [markdown]
# # Langkah Modul

# %%
import pandas as pd
path = "dataMissingValue.csv"
df = pd.read_csv(path)
df
# Out:
#   Name   School Level Blood Type   Age   Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0       apple        36.0
# 1    B    High School        NaN  17.0      banana        41.0
# 2    C    High School        NaN   NaN  watermelon         NaN
# 3    D    High School        NaN  16.0         NaN        38.0
# 4    E  Middle School          B  15.0      banana        37.0
# 5    F  Middle School        NaN  14.0      grapes         NaN
# 6    G  Middle School          O   NaN       mango        36.0
# 7    H    High School          A  16.0      papaya        39.0
# 8    I    High School        NaN  18.0         NaN        40.0
# 9    J  Middle School        NaN   NaN     avocado        35.0

# %%
import pandas as pd
path = "dataMissingValue.csv"
df = pd.read_csv(path)
df.isnull().sum()
# Out:
# Name            0
# School Level    0
# Blood Type      6
# Age             3
# Fav Fruit       2
# Shoe Chart      2
# dtype: int64

# %%
percent_missing = 100*df.isnull().mean()
percent_missing
# Out:
# Name             0.0
# School Level     0.0
# Blood Type      60.0
# Age             30.0
# Fav Fruit       20.0
# Shoe Chart      20.0
# dtype: float64

# %%
df.dropna(axis=0)
# Out:
#   Name   School Level Blood Type   Age Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0     apple        36.0
# 4    E  Middle School          B  15.0    banana        37.0
# 7    H    High School          A  16.0    papaya        39.0

# %%
df.dropna(axis=1)
# Out:
#   Name   School Level
# 0    A    High School
# 1    B    High School
# 2    C    High School
# 3    D    High School
# 4    E  Middle School
# 5    F  Middle School
# 6    G  Middle School
# 7    H    High School
# 8    I    High School
# 9    J  Middle School

# %%
df.dropna(thresh=5)
# Out:
#   Name   School Level Blood Type   Age Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0     apple        36.0
# 1    B    High School        NaN  17.0    banana        41.0
# 4    E  Middle School          B  15.0    banana        37.0
# 6    G  Middle School          O   NaN     mango        36.0
# 7    H    High School          A  16.0    papaya        39.0

# %%
df.dropna(subset=['Age'])
#menghspus Nan dalam kolom age
# Out:
#   Name   School Level Blood Type   Age Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0     apple        36.0
# 1    B    High School        NaN  17.0    banana        41.0
# 3    D    High School        NaN  16.0       NaN        38.0
# 4    E  Middle School          B  15.0    banana        37.0
# 5    F  Middle School        NaN  14.0    grapes         NaN
# 7    H    High School          A  16.0    papaya        39.0
# 8    I    High School        NaN  18.0       NaN        40.0

# %%
df_drop = df.drop(columns = 'Blood Type')
df_drop
# Out:
#   Name   School Level   Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.0       apple        36.0
# 1    B    High School  17.0      banana        41.0
# 2    C    High School   NaN  watermelon         NaN
# 3    D    High School  16.0         NaN        38.0
# 4    E  Middle School  15.0      banana        37.0
# 5    F  Middle School  14.0      grapes         NaN
# 6    G  Middle School   NaN       mango        36.0
# 7    H    High School  16.0      papaya        39.0
# 8    I    High School  18.0         NaN        40.0
# 9    J  Middle School   NaN     avocado        35.0

# %%
df_filled = df_drop.copy()
df_filled['Age'] = df['Age'].fillna(df['Age'].mean())
df_filled

#Menghitung nilai rata-rata dari kolom Age dan mengisi nilai yg kosongdengan nilai rata-rata
# Out:
#   Name   School Level        Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.000000       apple        36.0
# 1    B    High School  17.000000      banana        41.0
# 2    C    High School  15.857143  watermelon         NaN
# 3    D    High School  16.000000         NaN        38.0
# 4    E  Middle School  15.000000      banana        37.0
# 5    F  Middle School  14.000000      grapes         NaN
# 6    G  Middle School  15.857143       mango        36.0
# 7    H    High School  16.000000      papaya        39.0
# 8    I    High School  18.000000         NaN        40.0
# 9    J  Middle School  15.857143     avocado        35.0

# %%
df_filled['Shoe Chart'] = df['Shoe Chart'].fillna(df['Shoe Chart'].median())
df_filled 
#Menghitung nilai median dari kolom Shoe Chart dan mengisi nilai yg kosongdengan nilai median
# Out:
#   Name   School Level        Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.000000       apple        36.0
# 1    B    High School  17.000000      banana        41.0
# 2    C    High School  15.857143  watermelon        37.5
# 3    D    High School  16.000000         NaN        38.0
# 4    E  Middle School  15.000000      banana        37.0
# 5    F  Middle School  14.000000      grapes        37.5
# 6    G  Middle School  15.857143       mango        36.0
# 7    H    High School  16.000000      papaya        39.0
# 8    I    High School  18.000000         NaN        40.0
# 9    J  Middle School  15.857143     avocado        35.0

# %%
df_filled['Fav Fruit'] = df['Fav Fruit'].fillna(df['Fav Fruit'].mode().iloc[0])
df_filled
#Menghitung nilai modus dari kolom Fav Fruit dan mengisi nilai yg kosongdengan nilai modus
# Out:
#   Name   School Level        Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.000000       apple        36.0
# 1    B    High School  17.000000      banana        41.0
# 2    C    High School  15.857143  watermelon        37.5
# 3    D    High School  16.000000      banana        38.0
# 4    E  Middle School  15.000000      banana        37.0
# 5    F  Middle School  14.000000      grapes        37.5
# 6    G  Middle School  15.857143       mango        36.0
# 7    H    High School  16.000000      papaya        39.0
# 8    I    High School  18.000000      banana        40.0
# 9    J  Middle School  15.857143     avocado        35.0

# %%
df_filled2 = df_drop.copy()
df_filled2['Shoe Chart'] = df_filled2['Shoe Chart'].replace("", None).bfill()
df_filled2
#Mengisi nilai kosong pada kolom Shoe Chart dengan nilai sebelumnya (backfill)
# Out:
#   Name   School Level   Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.0       apple        36.0
# 1    B    High School  17.0      banana        41.0
# 2    C    High School   NaN  watermelon        38.0
# 3    D    High School  16.0         NaN        38.0
# 4    E  Middle School  15.0      banana        37.0
# 5    F  Middle School  14.0      grapes        36.0
# 6    G  Middle School   NaN       mango        36.0
# 7    H    High School  16.0      papaya        39.0
# 8    I    High School  18.0         NaN        40.0
# 9    J  Middle School   NaN     avocado        35.0

# %%
df_filled2['Fav Fruit'] = df_filled2['Fav Fruit'].replace("", None).ffill()
df_filled2
#Mengisi nilai kosong pada kolom Fav Fruit dengan nilai sebelumnya (forward fill)
# Out:
#   Name   School Level   Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.0       apple        36.0
# 1    B    High School  17.0      banana        41.0
# 2    C    High School   NaN  watermelon        38.0
# 3    D    High School  16.0  watermelon        38.0
# 4    E  Middle School  15.0      banana        37.0
# 5    F  Middle School  14.0      grapes        36.0
# 6    G  Middle School   NaN       mango        36.0
# 7    H    High School  16.0      papaya        39.0
# 8    I    High School  18.0      papaya        40.0
# 9    J  Middle School   NaN     avocado        35.0

# %%
path = "weight-height_outlier.csv"
df2 = pd.read_csv(path)
df2
#Menghapus outlier pada kolom Height dan Weight dengan menggunakan metode IQR (Interquartile Range)
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
import seaborn as sns
sns.boxplot(df2['Height'])
#import seaborn as sns
# Out:
# <Axes: ylabel='Height'>

# %%
import numpy as np
# Identifikasi Q1 Q3
q1, q3 = np.percentile(df2['Height'], [25, 75])
# Hitung IQR
iqr = q3 - q1
# Cari lower dan upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Hapus outliers
clean_data = df2[(df2['Height'] >= lower_bound)
 & (df2['Height'] <= upper_bound)]
sns.boxplot(clean_data['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
sns.boxplot(df2['Weight'])
# Out:
# <Axes: ylabel='Weight'>

# %%
# Identifikasi Q1 Q3
q1, q3 = np.percentile(df2['Weight'], [25, 75])
# Hitung IQR
iqr = q3 - q1
# Cari lower dan upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Hapus outliers
clean_data = df2[(df2['Weight'] >= lower_bound)
 & (df2['Weight'] <= upper_bound)]
sns.boxplot(clean_data['Weight'])
# Out:
# <Axes: ylabel='Weight'>

# %%
import matplotlib.pyplot as plt
# Membuat daftar kolom yang ingin dianalisis, yaitu "Weight" dan "Height".
columns_to_plot = ['Weight', 'Height']
# Memastikan kolom ada di dataset
columns_to_plot = [col for col in columns_to_plot if col in df2.columns]
fig, axs = plt.subplots(len(columns_to_plot), 1, dpi=95, figsize=(7, 5 * len(columns_to_plot)))
if len(columns_to_plot) == 1:
 axs = [axs]
for i, col in enumerate(columns_to_plot):
 axs[i].boxplot(df2[col], vert=False)
 axs[i].set_ylabel(col)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5576\2198912984.py:10: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(df2[col], vert=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_5576\2198912984.py:10: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(df2[col], vert=False)

# %%
import pandas as pd

# Ganti dengan nama file dataset yang memiliki kolom Height dan Weight
df2 = pd.read_csv("weight-height_outlier.csv")

# Cek apakah data berhasil dibaca
df2.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
import numpy as np
import matplotlib.pyplot as plt

def remove_outliers_sequentially(df2, columns):
    df_cleaned = df2.copy()

    for col in columns:
        # PERBAIKAN: seluruh isi for menjorok ke dalam
        q1, q3 = np.percentile(df_cleaned[col], [25, 75])
        iqr = q3 - q1
        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)

        # PERBAIKAN: lengkapi kondisi batas atas dan kurung
        df_cleaned = df_cleaned[
            (df_cleaned[col] >= lower_bound) &
            (df_cleaned[col] <= upper_bound)
        ]

    return df_cleaned  # PERBAIKAN: di luar for

# Terapkan fungsi untuk menghapus outliers dari "Height" dan "Weight"
clean_data = remove_outliers_sequentially(df2, ['Height', 'Weight'])

# Plot boxplots setelah menghapus outliers
columns_to_plot = ['Weight', 'Height']

# Baris yang diperbaiki
fig, axs = plt.subplots(len(columns_to_plot), 1,dpi=95,figsize=(7, 5 * len(columns_to_plot)))

if len(columns_to_plot) == 1:
    axs = [axs]

for i, col in enumerate(columns_to_plot):
    axs[i].boxplot(clean_data[col], vert=False)
    axs[i].set_ylabel(col)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\1839183129.py:39: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(clean_data[col], vert=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\1839183129.py:39: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(clean_data[col], vert=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
# Memisahkan kolom numerik dan non-numerik
numeric_cols = clean_data.select_dtypes(include=[np.number]).columns # Ambil kolom
non_numeric_cols = clean_data.select_dtypes(exclude=[np.number]).columns # Ambil k
rescaled_numeric = scaler.fit_transform(clean_data[numeric_cols])
rescaled_numeric[:]
# Out:
# array([[0.83480376, 0.92524773],
#        [0.6086688 , 0.49939825],
#        [0.84654949, 0.76925146],
#        ...,
#        [0.38928431, 0.31834619],
#        [0.61993463, 0.50764944],
#        [0.30339752, 0.23901104]], shape=(9992, 2))

# %%
# Konversi kembali hasil scaling ke DataFrame
rescaled_df = pd.DataFrame(rescaled_numeric,columns=numeric_cols,index=clean_data.index)
# Gabungkan kembali dengan kolom non-numerik tanpa mengubah jumlah baris
final_df = pd.concat([clean_data[non_numeric_cols], rescaled_df], axis=1)

final_df
# Out:
#       Gender    Height    Weight
# 0       Male  0.834804  0.925248
# 1       Male  0.608669  0.499398
# 2       Male  0.846549  0.769251
# 3       Male  0.740332  0.808322
# 4       Male  0.657774  0.735053
# ...      ...       ...       ...
# 9995  Female  0.492177  0.362771
# 9996  Female  0.532113  0.545189
# 9997  Female  0.389284  0.318346
# 9998  Female  0.619935  0.507649
# 9999  Female  0.303398  0.239011
#
# [9992 rows x 3 columns]

# %% [markdown]
# # Tugas Sesi 3 Preprocessing

# %%
import pandas as pd

df = pd.read_csv("Titanic-Dataset.csv")

# Melihat jumlah missing value sebelum ditangani
print("Missing value sebelum:")
print(df.isnull().sum())
# Out:
# Missing value sebelum:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
for col in df.columns:
    if df[col].isnull().any():
        if pd.api.types.is_numeric_dtype(df[col]):
            nilai_pengganti = df[col].median()

            # Jika seluruh kolom kosong, gunakan 0
            if pd.isna(nilai_pengganti):
                nilai_pengganti = 0
        else:
            modus = df[col].mode()
            nilai_pengganti = modus.iloc[0] if not modus.empty else "Unknown"

        df[col] = df[col].fillna(nilai_pengganti)

# Semua kolom seharusnya menunjukkan 0
print("Missing value setelah:")
print(df.isnull().sum())
# Out:
# Missing value setelah:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df2 = pd.read_csv("diabetes.csv")

# Melihat nama kolom
print(df2.columns.tolist())

columns_to_plot = ['Glucose', 'BMI', 'Age']

# Boxplot sebelum penanganan outliers
fig, axs = plt.subplots(3, 1, figsize=(8, 9), dpi=95)

for i, col in enumerate(columns_to_plot):
    axs[i].boxplot(df2[col].dropna(), vert=False)
    axs[i].set_ylabel(col)
    axs[i].set_title(f"{col} sebelum penanganan")

plt.tight_layout()
plt.show()
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\369557506.py:15: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(df2[col].dropna(), vert=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\369557506.py:15: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(df2[col].dropna(), vert=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\369557506.py:15: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(df2[col].dropna(), vert=False)

# %%
def remove_outliers_sequentially(data, columns):
    df_cleaned = data.copy()

    for col in columns:
        q1 = df_cleaned[col].quantile(0.25)
        q3 = df_cleaned[col].quantile(0.75)
        iqr = q3 - q1

        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr

        # Hapus outliers; pertahankan nilai kosong jika ada
        mask = (
            df_cleaned[col].between(lower_bound, upper_bound)
            | df_cleaned[col].isna()
        )
        df_cleaned = df_cleaned[mask]

    return df_cleaned

clean_data = remove_outliers_sequentially(df2, columns_to_plot)

print("Jumlah baris sebelum:", len(df2))
print("Jumlah baris setelah:", len(clean_data))
print("Jumlah baris yang dihapus:", len(df2) - len(clean_data))
# Out:
# Jumlah baris sebelum: 768
# Jumlah baris setelah: 736
# Jumlah baris yang dihapus: 32

# %%
# Boxplot setelah penanganan outliers
fig, axs = plt.subplots(3, 1, figsize=(8, 9), dpi=95)

for i, col in enumerate(columns_to_plot):
    axs[i].boxplot(clean_data[col].dropna(), vert=False)
    axs[i].set_ylabel(col)
    axs[i].set_title(f"{col} setelah penanganan")

plt.tight_layout()
plt.show()
#
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\4124306336.py:5: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(clean_data[col].dropna(), vert=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\4124306336.py:5: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(clean_data[col].dropna(), vert=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_14592\4124306336.py:5: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(clean_data[col].dropna(), vert=False)
